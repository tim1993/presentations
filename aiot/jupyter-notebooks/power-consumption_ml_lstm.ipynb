# %% [markdown]
# # LSTM Model with Additional Features for TotalConsumption Prediction

# %% [markdown]
# ## Ziel:
# Das Notebook implementiert ein LSTM-Modell, das nicht nur **TotalConsumption**, sondern auch zusätzliche Features wie **Temperature**, **Humidity**, **Wind Speed**, **General Diffuse Flows** und **Diffuse Flows** berücksichtigt.
#
# ### Zusätzliche Features:
# - **Temperature**: Umgebungstemperatur
# - **Humidity**: Relative Luftfeuchtigkeit
# - **Wind Speed**: Windgeschwindigkeit
# - **General Diffuse Flows**: Diffuse Strahlung allgemein
# - **Diffuse Flows**: Diffuse Strahlung spezifisch

# %%
# %pip install pandas scikit-learn matplotlib seaborn plotly nbformat tensorflow==2.10.0 keras keras_tuner protobuf
# Out:
# Requirement already satisfied: pandas in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (5.24.1)
# Requirement already satisfied: nbformat in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (5.10.4)
# Requirement already satisfied: tensorflow==2.10.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (2.10.0)
# Requirement already satisfied: keras in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (2.10.0)
# Requirement already satisfied: keras_tuner in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (1.4.7)
# Requirement already satisfied: protobuf in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (3.19.6)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (20210226132247)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (3.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (24.2)
# Requirement already satisfied: setuptools in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (1.68.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from nbformat) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: requests in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from keras_tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from keras_tuner) (1.0.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10.0) (0.35.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from jsonschema>=2.6->nbformat) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from jsonschema>=2.6->nbformat) (0.21.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (307)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from requests->keras_tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from requests->keras_tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from requests->keras_tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from requests->keras_tuner) (2024.8.30)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (7.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\timsteiner\miniconda3\envs\tf_gpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Bibliotheken importieren
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Datenvorbereitung

# %%
# Daten laden
file_path = 'consumption-data/consumption.csv'
data = pd.read_csv(file_path)

# TotalConsumption berechnen
data['TotalConsumption'] = data['Zone 1 Power Consumption'] + data['Zone 2  Power Consumption'] + data['Zone 3  Power Consumption']

# Datumsformat und Index setzen
data['DateTime'] = pd.to_datetime(data['DateTime'])
data.set_index('DateTime', inplace=True)

# Zusätzliche Features einbeziehen
time_series = data[['TotalConsumption', 'Temperature', 'Humidity', 'Wind Speed', 'general diffuse flows', 'diffuse flows']]

# Skalierung vorbereiten
scaler = MinMaxScaler(feature_range=(0, 1))
target_scaler = MinMaxScaler(feature_range=(0, 1))

# Skalierung auf Zielwert und Features anwenden
scaled_target = target_scaler.fit_transform(time_series[['TotalConsumption']])
scaled_features = scaler.fit_transform(time_series.iloc[:, 1:])

# Kombinieren der skalierten Daten
combined_scaled = np.hstack([scaled_target, scaled_features])

# %%
# Funktion zur Sequenzgenerierung
def create_sequences(data, sequence_length):
    x, y = [], []
    for i in range(len(data) - sequence_length):
        x.append(data[i:i + sequence_length, 1:])  # Features
        y.append(data[i + sequence_length, 0])    # Zielwert (TotalConsumption)
    return np.array(x), np.array(y)

# Sequenzen erstellen
sequence_length = 64
x, y = create_sequences(combined_scaled, sequence_length)

print(x.shape, y.shape)

# Trainings- und Testdaten aufteilen
train_size = int(len(x) * 0.8)  # 80% der Daten für Training
x_train, y_train = x[:train_size], y[:train_size]
x_test, y_test = x[train_size:], y[train_size:]

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (52352, 64, 5) (52352,)
# (41881, 64, 5) (41881,)
# (10471, 64, 5) (10471,)

# %% [markdown]
# ## 2. LSTM-Modell erstellen und trainieren

# %%
# Modell erstellen
model = Sequential()

# Bidirektionale LSTM-Schicht
model.add(Bidirectional(LSTM(units=64, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2]))))
model.add(Dropout(0.2))

# Zusätzliche LSTM-Schicht
model.add(LSTM(units=64, return_sequences=False))
model.add(Dropout(0.2))

# Dense-Schichten
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=1))

# Kompilieren
model.compile(optimizer='adam', loss='mean_squared_error')

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.1, min_lr=1e-6)

# Training
history = model.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_test, y_test),
                    verbose=1, callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/20
# 655/655 [==============================] - 14s 17ms/step - loss: 0.0103 - val_loss: 0.0034 - lr: 0.0010
# Epoch 2/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0060 - val_loss: 0.0026 - lr: 0.0010
# Epoch 3/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0050 - val_loss: 0.0021 - lr: 0.0010
# Epoch 4/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0045 - val_loss: 0.0021 - lr: 0.0010
# Epoch 5/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0042 - val_loss: 0.0022 - lr: 0.0010
# Epoch 6/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0038 - val_loss: 0.0024 - lr: 0.0010
# Epoch 7/20
# 655/655 [==============================] - 10s 16ms/step - loss: 0.0037 - val_loss: 0.0025 - lr: 0.0010
# Epoch 8/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0035 - val_loss: 0.0020 - lr: 0.0010
# Epoch 9/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0028 - val_loss: 0.0022 - lr: 1.0000e-04
# Epoch 10/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0027 - val_loss: 0.0023 - lr: 1.0000e-04
# Epoch 11/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0027 - val_loss: 0.0022 - lr: 1.0000e-04
# Epoch 12/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0026 - val_loss: 0.0021 - lr: 1.0000e-04
# Epoch 13/20
# 655/655 [==============================] - 11s 16ms/step - loss: 0.0025 - val_loss: 0.0022 - lr: 1.0000e-04
# Epoch 14/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0024 - val_loss: 0.0022 - lr: 1.0000e-05
# Epoch 15/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0024 - val_loss: 0.0022 - lr: 1.0000e-05
# Epoch 16/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0024 - val_loss: 0.0022 - lr: 1.0000e-05
# Epoch 17/20
# 655/655 [==============================] - 10s 16ms/step - loss: 0.0024 - val_loss: 0.0022 - lr: 1.0000e-05
# Epoch 18/20
# 655/655 [==============================] - 10s 15ms/step - loss: 0.0024 - val_loss: 0.0022 - lr: 1.0000e-05

# %% [markdown]
# ## 3. Modellvorhersagen und Evaluierung

# %%
# Vorhersagen
full_predictions_scaled = model.predict(x)
full_predictions = target_scaler.inverse_transform(full_predictions_scaled)

# Tatsächliche Werte zurückskalieren
actual_values = target_scaler.inverse_transform(y.reshape(-1, 1))

# Testdaten-Vorhersagen zurückskalieren
test_predictions_scaled = model.predict(x_test)
test_predictions = target_scaler.inverse_transform(test_predictions_scaled)
test_actual_values = target_scaler.inverse_transform(y_test.reshape(-1, 1))

# Leistungsmetriken
mae = mean_absolute_error(test_actual_values, test_predictions)
rmse = mean_squared_error(test_actual_values, test_predictions, squared=False)
r2 = r2_score(test_actual_values, test_predictions)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Square Error (RMSE): {rmse}")
print(f"R-Squared (R2): {r2}")
# Out:
# 1636/1636 [==============================] - 11s 6ms/step
# 328/328 [==============================] - 3s 7ms/step
# Mean Absolute Error (MAE): 3266.0551234530844
# Root Mean Square Error (RMSE): 4386.892717238769
# R-Squared (R2): 0.9034027495646788
# c:\Users\TimSteiner\miniconda3\envs\tf_gpu\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# ## 4. Visualisierungen

# %%
# Zeitserienvergleich
plt.figure(figsize=(14, 5))
plt.plot(actual_values, label='Actual Total Consumption', color='blue')
plt.plot(full_predictions, label='Predicted Total Consumption', color='red', alpha=0.7)
plt.title('Actual vs Predicted Total Consumption (Full Dataset)')
plt.xlabel('Time Steps')
plt.ylabel('Total Power Consumption')
plt.legend()
plt.show()

# Fehlerverteilung
errors = test_actual_values - test_predictions
plt.figure(figsize=(10, 5))
plt.hist(errors, bins=50, color='purple', edgecolor='black')
plt.title('Error Distribution (Test Data)')
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')
plt.show()

# Streudiagramm
plt.figure(figsize=(7, 7))
plt.scatter(test_actual_values, test_predictions, alpha=0.5, color='green')
plt.plot([min(test_actual_values), max(test_actual_values)],
         [min(test_actual_values), max(test_actual_values)],
         color='red', linestyle='--', label='Perfect Prediction')
plt.title('Scatter Plot: Actual vs Predicted Values (Test Data)')
plt.xlabel('Actual Total Consumption')
plt.ylabel('Predicted Total Consumption')
plt.legend()
plt.show()
